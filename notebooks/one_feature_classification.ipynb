# %%
import numpy as np
from datasets import load_from_disk
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tasks=['Length', 'Depth', 'CoordinationInversion', 'BigramShift', 'OddManOut', 'Tense', 'TopConstituents', 'WordContent', 'ObjNumber', 'SubjNumber']
outlier_dimensions = [61, 77, 82, 97, 217, 219, 240, 330, 361, 453, 494, 496, 498, 551, 570, 588, 656, 731, 749]

# %%
disk_path = "drive/MyDrive"
zip_path1 = '/content/drive/MyDrive/probing.zip'
zip_path2 = '/content/drive/MyDrive/probing_numbers.zip'
data_path = "."

# %%
! unzip $zip_path1 -d  $data_path
# Out:
# Archive:  /content/drive/MyDrive/probing.zip
#    creating: ./BigramShift.hf/
#   inflating: ./BigramShift.hf/dataset_dict.json
#    creating: ./BigramShift.hf/test/
#    creating: ./BigramShift.hf/train/
#    creating: ./BigramShift.hf/dev/
#   inflating: ./BigramShift.hf/test/state.json
#   inflating: ./BigramShift.hf/test/dataset_info.json
#   inflating: ./BigramShift.hf/test/data-00000-of-00001.arrow
#   inflating: ./BigramShift.hf/train/state.json
#   inflating: ./BigramShift.hf/train/dataset_info.json
#   inflating: ./BigramShift.hf/train/data-00000-of-00001.arrow
#   inflating: ./BigramShift.hf/dev/state.json
#   inflating: ./BigramShift.hf/dev/dataset_info.json
#   inflating: ./BigramShift.hf/dev/data-00000-of-00001.arrow
#    creating: ./CoordinationInversion.hf/
#   inflating: ./CoordinationInversion.hf/.DS_Store
#   inflating: ./__MACOSX/CoordinationInversion.hf/._.DS_Store
#   inflating: ./CoordinationInversion.hf/dataset_dict.json
#   inflating: ./__MACOSX/CoordinationInversion.hf/._dataset_dict.json
#    creating: ./CoordinationInversion.hf/test/
#    creating: ./CoordinationInversion.hf/train/
#    creating: ./CoordinationInversion.hf/dev/
#   inflating: ./CoordinationInversion.hf/test/state.json
#   inflating: ./CoordinationInversion.hf/test/dataset_info.json
#   inflating: ./CoordinationInversion.hf/test/data-00000-of-00001.arrow
#   inflating: ./CoordinationInversion.hf/train/state.json
#   inflating: ./CoordinationInversion.hf/train/dataset_info.json
#   inflating: ./CoordinationInversion.hf/train/data-00000-of-00001.arrow
#   inflating: ./CoordinationInversion.hf/dev/state.json
#   inflating: ./CoordinationInversion.hf/dev/dataset_info.json
#   inflating: ./CoordinationInversion.hf/dev/data-00000-of-00001.arrow
#    creating: ./Depth.hf/
#   inflating: ./Depth.hf/dataset_dict.json
#    creating: ./Depth.hf/test/
#    creating: ./Depth.hf/train/
#    creating: ./Depth.hf/dev/
#   inflating: ./Depth.hf/test/state.json
#   inflating: ./Depth.hf/test/dataset_info.json
#   inflating: ./Depth.hf/test/data-00000-of-00001.arrow
#   inflating: ./Depth.hf/train/state.json
#   inflating: ./Depth.hf/train/dataset_info.json
#   inflating: ./Depth.hf/train/data-00000-of-00001.arrow
#   inflating: ./Depth.hf/dev/state.json
#   inflating: ./Depth.hf/dev/dataset_info.json
#   inflating: ./Depth.hf/dev/data-00000-of-00001.arrow
#    creating: ./Length.hf/
#   inflating: ./Length.hf/.DS_Store
#   inflating: ./__MACOSX/Length.hf/._.DS_Store
#   inflating: ./Length.hf/dataset_dict.json
#    creating: ./Length.hf/test/
#    creating: ./Length.hf/train/
#    creating: ./Length.hf/dev/
#   inflating: ./Length.hf/test/state.json
#   inflating: ./Length.hf/test/dataset_info.json
#   inflating: ./Length.hf/test/data-00000-of-00001.arrow
#   inflating: ./Length.hf/train/state.json
#   inflating: ./Length.hf/train/dataset_info.json
#   inflating: ./Length.hf/train/data-00000-of-00001.arrow
#   inflating: ./Length.hf/dev/state.json
#   inflating: ./Length.hf/dev/dataset_info.json
#   inflating: ./Length.hf/dev/data-00000-of-00001.arrow
#    creating: ./OddManOut.hf/
#   inflating: ./OddManOut.hf/.DS_Store
#   inflating: ./__MACOSX/OddManOut.hf/._.DS_Store
#   inflating: ./OddManOut.hf/dataset_dict.json
#    creating: ./OddManOut.hf/test/
#    creating: ./OddManOut.hf/train/
#    creating: ./OddManOut.hf/dev/
#   inflating: ./OddManOut.hf/test/state.json
#   inflating: ./OddManOut.hf/test/dataset_info.json
#   inflating: ./OddManOut.hf/test/data-00000-of-00001.arrow
#   inflating: ./OddManOut.hf/train/state.json
#   inflating: ./OddManOut.hf/train/dataset_info.json
#   inflating: ./OddManOut.hf/train/data-00000-of-00001.arrow
#   inflating: ./OddManOut.hf/dev/state.json
#   inflating: ./OddManOut.hf/dev/dataset_info.json
#   inflating: ./OddManOut.hf/dev/data-00000-of-00001.arrow
#    creating: ./Tense.hf/
#   inflating: ./Tense.hf/dataset_dict.json
#    creating: ./Tense.hf/test/
#    creating: ./Tense.hf/train/
#    creating: ./Tense.hf/dev/
#   inflating: ./Tense.hf/test/state.json
#   inflating: ./Tense.hf/test/dataset_info.json
#   inflating: ./Tense.hf/test/data-00000-of-00001.arrow
#   inflating: ./Tense.hf/train/state.json
#   inflating: ./Tense.hf/train/dataset_info.json
#   inflating: ./Tense.hf/train/data-00000-of-00001.arrow
#   inflating: ./Tense.hf/dev/state.json
#   inflating: ./Tense.hf/dev/dataset_info.json
#   inflating: ./Tense.hf/dev/data-00000-of-00001.arrow
#    creating: ./TopConstituents.hf/
#   inflating: ./TopConstituents.hf/.DS_Store
#   inflating: ./__MACOSX/TopConstituents.hf/._.DS_Store
#   inflating: ./TopConstituents.hf/dataset_dict.json
#    creating: ./TopConstituents.hf/test/
#    creating: ./TopConstituents.hf/train/
#    creating: ./TopConstituents.hf/dev/
#   inflating: ./TopConstituents.hf/test/state.json
#   inflating: ./TopConstituents.hf/test/dataset_info.json
#   inflating: ./TopConstituents.hf/test/data-00000-of-00001.arrow
#   inflating: ./TopConstituents.hf/train/state.json
#   inflating: ./TopConstituents.hf/train/dataset_info.json
#   inflating: ./TopConstituents.hf/train/data-00000-of-00001.arrow
#   inflating: ./TopConstituents.hf/dev/state.json
#   inflating: ./TopConstituents.hf/dev/dataset_info.json
#   inflating: ./TopConstituents.hf/dev/data-00000-of-00001.arrow
#    creating: ./WordContent.hf/
#   inflating: ./WordContent.hf/dataset_dict.json
#    creating: ./WordContent.hf/test/
#    creating: ./WordContent.hf/train/
#    creating: ./WordContent.hf/dev/
#   inflating: ./WordContent.hf/test/state.json
#   inflating: ./WordContent.hf/test/dataset_info.json
#   inflating: ./WordContent.hf/test/data-00000-of-00001.arrow
#   inflating: ./WordContent.hf/train/state.json
#   inflating: ./WordContent.hf/train/dataset_info.json
#   inflating: ./WordContent.hf/train/data-00000-of-00001.arrow
#   inflating: ./WordContent.hf/dev/state.json
#   inflating: ./WordContent.hf/dev/dataset_info.json
#   inflating: ./WordContent.hf/dev/data-00000-of-00001.arrow

# %%
! unzip $zip_path2 -d  $data_path
# Out:
# Archive:  /content/drive/MyDrive/probing_numbers.zip
#    creating: ./ObjNumber.hf/
#   inflating: ./ObjNumber.hf/dataset_dict.json
#    creating: ./ObjNumber.hf/test/
#    creating: ./ObjNumber.hf/train/
#    creating: ./ObjNumber.hf/dev/
#   inflating: ./ObjNumber.hf/test/state.json
#   inflating: ./ObjNumber.hf/test/dataset_info.json
#   inflating: ./ObjNumber.hf/test/data-00000-of-00001.arrow
#   inflating: ./ObjNumber.hf/train/state.json
#   inflating: ./ObjNumber.hf/train/dataset_info.json
#   inflating: ./ObjNumber.hf/train/data-00000-of-00001.arrow
#   inflating: ./ObjNumber.hf/dev/state.json
#   inflating: ./ObjNumber.hf/dev/dataset_info.json
#   inflating: ./ObjNumber.hf/dev/data-00000-of-00001.arrow
#    creating: ./SubjNumber.hf/
#   inflating: ./SubjNumber.hf/.DS_Store
#   inflating: ./__MACOSX/SubjNumber.hf/._.DS_Store
#   inflating: ./SubjNumber.hf/dataset_dict.json
#    creating: ./SubjNumber.hf/test/
#    creating: ./SubjNumber.hf/train/
#    creating: ./SubjNumber.hf/dev/
#   inflating: ./SubjNumber.hf/test/state.json
#   inflating: ./SubjNumber.hf/test/dataset_info.json
#   inflating: ./SubjNumber.hf/test/data-00000-of-00001.arrow
#   inflating: ./SubjNumber.hf/train/state.json
#   inflating: ./SubjNumber.hf/train/dataset_info.json
#   inflating: ./SubjNumber.hf/train/data-00000-of-00001.arrow
#   inflating: ./SubjNumber.hf/dev/state.json
#   inflating: ./SubjNumber.hf/dev/dataset_info.json
#   inflating: ./SubjNumber.hf/dev/data-00000-of-00001.arrow

# %%
def one_feat_classif(task, n_features=768):
  d=[]
  embed = load_from_disk('/content/'+task+'.hf')
  X_train_full=np.array(embed['train']['X'])
  y_train=np.array(embed['train']['y'])
  X_test_full=np.array(embed['test']['X'])
  y_test=np.array(embed['test']['y'])

  for ind in tqdm(range(n_features)):
    model=LogisticRegression()
    model.fit(X_train_full[:,ind].reshape(-1, 1), y_train)
    y_pred=model.predict(X_test_full[:,ind].reshape(-1,1))
    acc=accuracy_score(y_test, y_pred)
    d.append(acc)
  d=np.array(d)
  return d

# %%
acc_objnumber=one_feat_classif('ObjNumber')
# Out:
# 100%|██████████| 768/768 [00:59<00:00, 12.97it/s]

# %%
np.save('accuracy_ObjNumber', acc_objnumber)

# %%
acc_subjnumber=one_feat_classif('SubjNumber')
# Out:
# 100%|██████████| 768/768 [01:20<00:00,  9.56it/s]

# %%
np.save('accuracy_SubjNumber', acc_subjnumber)

# %%
acc_length=one_feat_classif('Length')
# Out:
# 100%|██████████| 768/768 [06:06<00:00,  2.10it/s]

# %%
np.save('accuracy_Length', acc_length)

# %%
for task in tasks[1:-3]:
  acc_task=one_feat_classif(task)
  np.save('accuracy_'+task, acc_task)
# Out:
# 100%|██████████| 768/768 [16:51<00:00,  1.32s/it]
# 100%|██████████| 768/768 [00:55<00:00, 13.72it/s]
# 100%|██████████| 768/768 [01:01<00:00, 12.58it/s]
# 100%|██████████| 768/768 [01:18<00:00,  9.74it/s]
# 100%|██████████| 768/768 [01:06<00:00, 11.50it/s]
# 100%|██████████| 768/768 [18:14<00:00,  1.43s/it]

# %%
#random features
num_features=768
rng=np.random.default_rng(seed=23)
rand_index=rng.integers(0,num_features,size=20)

# %%
df={}
rand_class=[]

# %%
for task in tasks:
  d=[]
  embed = load_from_disk('/content/'+task+'.hf')
  X_train_full=np.array(embed['train']['X'])
  y_train=np.array(embed['train']['y'])
  X_test_full=np.array(embed['test']['X'])
  y_test=np.array(embed['test']['y'])
  rand_class.append(1/len(np.unique(y_train)))
  s_acc=0
  for ind in rand_index:
    model=LogisticRegression()
    model.fit(X_train_full[:,ind].reshape(-1, 1), y_train)
    y_pred=model.predict(X_test_full[:,ind].reshape(-1,1))
    acc=accuracy_score(y_pred,y_test)
    s_acc+=acc
  mean_acc=s_acc/20
  d.append(mean_acc)

  for od in outlier_dimensions:
    model=LogisticRegression()
    X_tr=X_train_full[:,od]
    model.fit(X_tr.reshape(-1, 1), y_train)
    y_pred=model.predict(X_test_full[:,od].reshape(-1,1))
    acc=accuracy_score(y_pred,y_test)
    d.append(acc)

  df[task]=d

# %%
a=['random features']
a.extend(outlier_dimensions)
table = pd.DataFrame(data=df, index=a)

# %%
table.loc['random classification']=rand_class

# %%
table
# Out:
#                          Length     Depth  CoordinationInversion  BigramShift  \
# random features        0.190411  0.180640               0.513462      0.55564
# 61                     0.214186  0.181700               0.512597      0.51960
# 77                     0.438375  0.177000               0.518896      0.57320
# 82                     0.264306  0.182300               0.533993      0.68040
# 97                     0.203882  0.176300               0.522496      0.62540
# 217                    0.281513  0.190000               0.521596      0.50920
# 219                    0.298719  0.202600               0.523295      0.52600
# 240                    0.236595  0.175200               0.492302      0.52100
# 330                    0.216587  0.182700               0.501600      0.50430
# 361                    0.204582  0.182000               0.506599      0.54920
# 453                    0.225790  0.176500               0.507598      0.54480
# 494                    0.266006  0.181000               0.539092      0.57230
# 496                    0.223790  0.195900               0.494601      0.52550
# 498                    0.234494  0.189800               0.505199      0.53880
# 551                    0.293117  0.177300               0.509498      0.50690
# 570                    0.194978  0.185000               0.495101      0.55010
# 588                    0.214986  0.179000               0.509498      0.54210
# 656                    0.207483  0.180700               0.499800      0.52130
# 731                    0.203381  0.194900               0.518096      0.56690
# 749                    0.233193  0.180400               0.502799      0.61160
# random classification  0.166667  0.142857               0.500000      0.50000
#
#                        OddManOut    Tense  TopConstituents  WordContent  \
# random features          0.51775  0.53609           0.0693      0.00191
# 61                       0.51260  0.58160           0.0712      0.00230
# 77                       0.54490  0.56360           0.0904      0.00170
# 82                       0.57270  0.50250           0.0830      0.00150
# 97                       0.52800  0.66940           0.0767      0.00240
# 217                      0.51830  0.57110           0.0790      0.00160
# 219                      0.50230  0.50650           0.0773      0.00200
# 240                      0.50680  0.48360           0.0697      0.00180
# 330                      0.51990  0.49300           0.0794      0.00220
# 361                      0.50890  0.54770           0.0650      0.00160
# 453                      0.53220  0.49530           0.0722      0.00260
# 494                      0.53310  0.51480           0.0722      0.00150
# 496                      0.50550  0.54340           0.0800      0.00240
# 498                      0.51000  0.61250           0.0944      0.00250
# 551                      0.51710  0.56720           0.0722      0.00190
# 570                      0.51510  0.57320           0.0663      0.00190
# 588                      0.52580  0.59700           0.0946      0.00260
# 656                      0.50240  0.49270           0.0680      0.00190
# 731                      0.50600  0.53870           0.0794      0.00180
# 749                      0.52700  0.63860           0.0675      0.00190
# random classification    0.50000  0.50000           0.0500      0.00100
#
#                        ObjNumber  SubjNumber
# random features         0.527415    0.527845
# 61                      0.504700    0.487300
# 77                      0.507400    0.511500
# 82                      0.535600    0.509400
# 97                      0.566000    0.580100
# 217                     0.513800    0.512200
# 219                     0.529200    0.508400
# 240                     0.500700    0.488100
# 330                     0.515800    0.525700
# 361                     0.519700    0.529200
# 453                     0.553200    0.573800
# 494                     0.520800    0.520400
# 496                     0.508800    0.514100
# 498                     0.535500    0.465700
# 551                     0.521800    0.537100
# 570                     0.599900    0.575000
# 588                     0.526600    0.500000
# 656                     0.492000    0.491800
# 731                     0.538700    0.550200
# 749                     0.565600    0.573900
# random classification   0.500000    0.500000
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
table.to_csv('1featclassif.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-80ef67d029c8> in <cell line: 1>()
# ----> 1 table.to_csv('1featclassif.csv')
#
# NameError: name 'table' is not defined

# %%
import pandas as pd
import numpy as np
table1= pd.read_csv('1featclassif.csv')

# %%
table1
# Out:
#                Unnamed: 0    Length     Depth  CoordinationInversion  \
# 0         random features  0.190411  0.180640               0.513462
# 1                      61  0.214186  0.181700               0.512597
# 2                      77  0.438375  0.177000               0.518896
# 3                      82  0.264306  0.182300               0.533993
# 4                      97  0.203882  0.176300               0.522496
# 5                     217  0.281513  0.190000               0.521596
# 6                     219  0.298719  0.202600               0.523295
# 7                     240  0.236595  0.175200               0.492302
# 8                     330  0.216587  0.182700               0.501600
# 9                     361  0.204582  0.182000               0.506599
# 10                    453  0.225790  0.176500               0.507598
# 11                    494  0.266006  0.181000               0.539092
# 12                    496  0.223790  0.195900               0.494601
# 13                    498  0.234494  0.189800               0.505199
# 14                    551  0.293117  0.177300               0.509498
# 15                    570  0.194978  0.185000               0.495101
# 16                    588  0.214986  0.179000               0.509498
# 17                    656  0.207483  0.180700               0.499800
# 18                    731  0.203381  0.194900               0.518096
# 19                    749  0.233193  0.180400               0.502799
# 20  random classification  0.166667  0.142857               0.500000
#
#     BigramShift  OddManOut    Tense  TopConstituents  WordContent  ObjNumber  \
# 0       0.55564    0.51775  0.53609           0.0693      0.00191   0.527415
# 1       0.51960    0.51260  0.58160           0.0712      0.00230   0.504700
# 2       0.57320    0.54490  0.56360           0.0904      0.00170   0.507400
# 3       0.68040    0.57270  0.50250           0.0830      0.00150   0.535600
# 4       0.62540    0.52800  0.66940           0.0767      0.00240   0.566000
# 5       0.50920    0.51830  0.57110           0.0790      0.00160   0.513800
# 6       0.52600    0.50230  0.50650           0.0773      0.00200   0.529200
# 7       0.52100    0.50680  0.48360           0.0697      0.00180   0.500700
# 8       0.50430    0.51990  0.49300           0.0794      0.00220   0.515800
# 9       0.54920    0.50890  0.54770           0.0650      0.00160   0.519700
# 10      0.54480    0.53220  0.49530           0.0722      0.00260   0.553200
# 11      0.57230    0.53310  0.51480           0.0722      0.00150   0.520800
# 12      0.52550    0.50550  0.54340           0.0800      0.00240   0.508800
# 13      0.53880    0.51000  0.61250           0.0944      0.00250   0.535500
# 14      0.50690    0.51710  0.56720           0.0722      0.00190   0.521800
# 15      0.55010    0.51510  0.57320           0.0663      0.00190   0.599900
# 16      0.54210    0.52580  0.59700           0.0946      0.00260   0.526600
# 17      0.52130    0.50240  0.49270           0.0680      0.00190   0.492000
# 18      0.56690    0.50600  0.53870           0.0794      0.00180   0.538700
# 19      0.61160    0.52700  0.63860           0.0675      0.00190   0.565600
# 20      0.50000    0.50000  0.50000           0.0500      0.00100   0.500000
#
#     SubjNumber
# 0     0.527845
# 1     0.487300
# 2     0.511500
# 3     0.509400
# 4     0.580100
# 5     0.512200
# 6     0.508400
# 7     0.488100
# 8     0.525700
# 9     0.529200
# 10    0.573800
# 11    0.520400
# 12    0.514100
# 13    0.465700
# 14    0.537100
# 15    0.575000
# 16    0.500000
# 17    0.491800
# 18    0.550200
# 19    0.573900
# 20    0.500000

# %%
table1['TopConstituents']=np.round(table1['TopConstituents'], 3)
table1['WordContent']=np.round(table1['WordContent'], 4)
table1[table1.columns.drop(['TopConstituents', 'WordContent', 'Unnamed: 0'])]=np.round(table1[table1.columns.drop(['TopConstituents', 'WordContent', 'Unnamed: 0'])],2)
table1=table1.T
table1.columns=table1.loc['Unnamed: 0']
table1=table1.drop(['Unnamed: 0'], axis=0)

# %%
table1.iloc[:,:11]
# Out:
# Unnamed: 0            random features      61      77      82      97     217  \
# Length                           0.19    0.21    0.44    0.26     0.2    0.28
# Depth                            0.18    0.18    0.18    0.18    0.18    0.19
# CoordinationInversion            0.51    0.51    0.52    0.53    0.52    0.52
# BigramShift                      0.56    0.52    0.57    0.68    0.63    0.51
# OddManOut                        0.52    0.51    0.54    0.57    0.53    0.52
# Tense                            0.54    0.58    0.56     0.5    0.67    0.57
# TopConstituents                 0.069   0.071    0.09   0.083   0.077   0.079
# WordContent                    0.0019  0.0023  0.0017  0.0015  0.0024  0.0016
# ObjNumber                        0.53     0.5    0.51    0.54    0.57    0.51
# SubjNumber                       0.53    0.49    0.51    0.51    0.58    0.51
#
# Unnamed: 0               219     240     330     361     453
# Length                   0.3    0.24    0.22     0.2    0.23
# Depth                    0.2    0.18    0.18    0.18    0.18
# CoordinationInversion   0.52    0.49     0.5    0.51    0.51
# BigramShift             0.53    0.52     0.5    0.55    0.54
# OddManOut                0.5    0.51    0.52    0.51    0.53
# Tense                   0.51    0.48    0.49    0.55     0.5
# TopConstituents        0.077    0.07   0.079   0.065   0.072
# WordContent            0.002  0.0018  0.0022  0.0016  0.0026
# ObjNumber               0.53     0.5    0.52    0.52    0.55
# SubjNumber              0.51    0.49    0.53    0.53    0.57

# %%
table1.iloc[:,11:]
# Out:
# Unnamed: 0                494     496     498     551     570     588     656  \
# Length                   0.27    0.22    0.23    0.29    0.19    0.21    0.21
# Depth                    0.18     0.2    0.19    0.18    0.18    0.18    0.18
# CoordinationInversion    0.54    0.49    0.51    0.51     0.5    0.51     0.5
# BigramShift              0.57    0.53    0.54    0.51    0.55    0.54    0.52
# OddManOut                0.53    0.51    0.51    0.52    0.52    0.53     0.5
# Tense                    0.51    0.54    0.61    0.57    0.57     0.6    0.49
# TopConstituents         0.072    0.08   0.094   0.072   0.066   0.095   0.068
# WordContent            0.0015  0.0024  0.0025  0.0019  0.0019  0.0026  0.0019
# ObjNumber                0.52    0.51    0.54    0.52     0.6    0.53    0.49
# SubjNumber               0.52    0.51    0.47    0.54    0.57     0.5    0.49
#
# Unnamed: 0                731     749 random classification
# Length                    0.2    0.23                  0.17
# Depth                    0.19    0.18                  0.14
# CoordinationInversion    0.52     0.5                   0.5
# BigramShift              0.57    0.61                   0.5
# OddManOut                0.51    0.53                   0.5
# Tense                    0.54    0.64                   0.5
# TopConstituents         0.079   0.068                  0.05
# WordContent            0.0018  0.0019                 0.001
# ObjNumber                0.54    0.57                   0.5
# SubjNumber               0.55    0.57                   0.5

# %%
table1.iloc[:,-1].T
# Out:
# Length                    0.17
# Depth                     0.14
# CoordinationInversion      0.5
# BigramShift                0.5
# OddManOut                  0.5
# Tense                      0.5
# TopConstituents           0.05
# WordContent              0.001
# ObjNumber                  0.5
# SubjNumber                 0.5
# Name: random classification, dtype: object

# %%
table1
# Out:
# Unnamed: 0            random features      61      77      82      97     217  \
# Length                           0.19    0.21    0.44    0.26     0.2    0.28
# Depth                            0.18    0.18    0.18    0.18    0.18    0.19
# CoordinationInversion            0.51    0.51    0.52    0.53    0.52    0.52
# BigramShift                      0.56    0.52    0.57    0.68    0.63    0.51
# OddManOut                        0.52    0.51    0.54    0.57    0.53    0.52
# Tense                            0.54    0.58    0.56     0.5    0.67    0.57
# TopConstituents                 0.069   0.071    0.09   0.083   0.077   0.079
# WordContent                    0.0019  0.0023  0.0017  0.0015  0.0024  0.0016
# ObjNumber                        0.53     0.5    0.51    0.54    0.57    0.51
# SubjNumber                       0.53    0.49    0.51    0.51    0.58    0.51
#
# Unnamed: 0               219     240     330     361  ...     494     496  \
# Length                   0.3    0.24    0.22     0.2  ...    0.27    0.22
# Depth                    0.2    0.18    0.18    0.18  ...    0.18     0.2
# CoordinationInversion   0.52    0.49     0.5    0.51  ...    0.54    0.49
# BigramShift             0.53    0.52     0.5    0.55  ...    0.57    0.53
# OddManOut                0.5    0.51    0.52    0.51  ...    0.53    0.51
# Tense                   0.51    0.48    0.49    0.55  ...    0.51    0.54
# TopConstituents        0.077    0.07   0.079   0.065  ...   0.072    0.08
# WordContent            0.002  0.0018  0.0022  0.0016  ...  0.0015  0.0024
# ObjNumber               0.53     0.5    0.52    0.52  ...    0.52    0.51
# SubjNumber              0.51    0.49    0.53    0.53  ...    0.52    0.51
#
# Unnamed: 0                498     551     570     588     656     731     749  \
# Length                   0.23    0.29    0.19    0.21    0.21     0.2    0.23
# Depth                    0.19    0.18    0.18    0.18    0.18    0.19    0.18
# CoordinationInversion    0.51    0.51     0.5    0.51     0.5    0.52     0.5
# BigramShift              0.54    0.51    0.55    0.54    0.52    0.57    0.61
# OddManOut                0.51    0.52    0.52    0.53     0.5    0.51    0.53
# Tense                    0.61    0.57    0.57     0.6    0.49    0.54    0.64
# TopConstituents         0.094   0.072   0.066   0.095   0.068   0.079   0.068
# WordContent            0.0025  0.0019  0.0019  0.0026  0.0019  0.0018  0.0019
# ObjNumber                0.54    0.52     0.6    0.53    0.49    0.54    0.57
# SubjNumber               0.47    0.54    0.57     0.5    0.49    0.55    0.57
#
# Unnamed: 0            random classification
# Length                                 0.17
# Depth                                  0.14
# CoordinationInversion                   0.5
# BigramShift                             0.5
# OddManOut                               0.5
# Tense                                   0.5
# TopConstituents                        0.05
# WordContent                           0.001
# ObjNumber                               0.5
# SubjNumber                              0.5
#
# [10 rows x 21 columns]
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.

# %%
df=pd.DataFrame()
for task in tasks:
  if task!='WordContent':
    data=np.load('accuracy_'+task+'.npy')
    df['Accuracy'+task]=np.sort(data)[::-1][:10]
    df['Index'+task]=np.argsort(data)[::-1][:10]

# %%
df
# Out:
#    AccuracyLength  IndexLength  AccuracyDepth  IndexDepth  \
# 0        0.438375           77         0.2045         734
# 1        0.298719          219         0.2034         180
# 2        0.293117          551         0.2033          74
# 3        0.282813           38         0.2026         219
# 4        0.281713          144         0.2023         397
# 5        0.281513          217         0.2010         539
# 6        0.268808          664         0.1998         133
# 7        0.266006          494         0.1980         185
# 8        0.264306           82         0.1970         245
# 9        0.262605          331         0.1964         514
#
#    AccuracyCoordinationInversion  IndexCoordinationInversion  \
# 0                       0.548490                         248
# 1                       0.542392                         666
# 2                       0.541292                          69
# 3                       0.539092                         494
# 4                       0.537493                         176
# 5                       0.536193                         516
# 6                       0.535993                         538
# 7                       0.535993                         729
# 8                       0.535193                         332
# 9                       0.535093                         360
#
#    AccuracyBigramShift  IndexBigramShift  AccuracyOddManOut  IndexOddManOut  \
# 0               0.6804                82             0.5727              82
# 1               0.6377               477             0.5645             331
# 2               0.6254                97             0.5522             248
# 3               0.6223               666             0.5449              77
# 4               0.6215               662             0.5416              69
# 5               0.6212               155             0.5414             611
# 6               0.6182               157             0.5405             342
# 7               0.6141               342             0.5393             420
# 8               0.6136               248             0.5378             157
# 9               0.6126               604             0.5363             662
#
#    AccuracyTense  IndexTense  AccuracyTopConstituents  IndexTopConstituents  \
# 0         0.6929         709                   0.1006                    16
# 1         0.6827         587                   0.0946                   588
# 2         0.6694          97                   0.0944                   498
# 3         0.6476         286                   0.0942                   624
# 4         0.6393          44                   0.0904                    77
# 5         0.6386         749                   0.0887                   179
# 6         0.6380         690                   0.0886                    81
# 7         0.6374         471                   0.0874                   138
# 8         0.6341         166                   0.0869                   384
# 9         0.6328         438                   0.0865                   331
#
#    AccuracyObjNumber  IndexObjNumber  AccuracySubjNumber  IndexSubjNumber
# 0             0.5999             570              0.6258              154
# 1             0.5977             154              0.6257              530
# 2             0.5959             379              0.6046              612
# 3             0.5931              93              0.6024              327
# 4             0.5927             739              0.5966              689
# 5             0.5900             760              0.5950              379
# 6             0.5895             443              0.5912              491
# 7             0.5856             327              0.5908              485
# 8             0.5824             530              0.5895               79
# 9             0.5802             698              0.5882              634

# %%
df.to_csv('1featclassif_all.csv')
